# %%
# !pip install feedparser
# !pip install feedparser psycopg2

# %%
import feedparser
import psycopg2
categories = {
    'Terrorism / protest / political unrest / riot': ['terrorism', 'protest', 'riot', 'political unrest','election','ruling','thread'],
    'Positive/Uplifting': ['hope', 'achievement', 'good', 'uplifting', 'positive','happy','motivated','medal','succes'],
    'Natural Disasters': ['earthquake', 'flood', 'hurricane', 'natural disaster','tsunami','astriod','blackhole','glacier'],
}

def classify_article(text):
    """Classify the article based on the presence of keywords."""
    text = text.lower() 
    for category, keywords in categories.items():
        for keyword in keywords:
            if keyword.lower() in text:
                return category
    return 'Others'

feed_urls = [
    'http://rss.cnn.com/rss/cnn_topstories.rss',
    'http://qz.com/feed',
    'http://feeds.foxnews.com/foxnews/politics',
    'http://feeds.reuters.com/reuters/businessNews',
    'http://feeds.feedburner.com/NewshourWorld',
    'https://feeds.bbci.co.uk/news/world/asia/india/rss.xml'
]

conn = psycopg2.connect(
    user="postgres", password="divya", host="localhost", port="5432", database="rss"
)
cur = conn.cursor()

for j, feed_url in enumerate(feed_urls):
    print(f"Parsing feed: {feed_url}")
    feed = feedparser.parse(feed_url)
    
    for i, entry in enumerate(feed.entries):
        Title = entry.title if 'title' in entry else 'No title'
        Links = entry.link if 'link' in entry else 'No link'
        Published = entry.published if 'published' in entry else 'No date'
        id = '{0}_{1}'.format(j, i)

      
        category = classify_article(Title + ' ' + (entry.summary if 'summary' in entry else ''))

        try:
             cur.execute(
                """
                INSERT INTO articles (id, "Title", "Links", "Published", "category")
                VALUES (%s, %s, %s, %s, %s)
                ON CONFLICT ("Links") DO UPDATE SET "category" = EXCLUDED."category";
                """,
                (id, Title, Links, Published, category)
            )
            conn.commit()  

            print(f"Inserted article: {Title} with category: {category}")

        except Exception as e:
            print(f"Error inserting article: {Title}. Error: {e}")


cur.close()
conn.close()
# Out:
# Parsing feed: http://rss.cnn.com/rss/cnn_topstories.rss
# Inserted article: Some on-air claims about Dominion Voting Systems were false, Fox News acknowledges in statement after deal is announced with category: Others
# Inserted article: Dominion still has pending lawsuits against election deniers such as Rudy Giuliani and Sidney Powell with category: Terrorism / protest / political unrest / riot
# Inserted article: Here are the 20 specific Fox broadcasts and tweets Dominion says were defamatory with category: Terrorism / protest / political unrest / riot
# Inserted article: Judge in Fox News-Dominion defamation trial: 'The parties have resolved their case' with category: Others
# Inserted article: 'Difficult to say with a straight face': Tapper reacts to Fox News' statement on settlement with category: Others
# Inserted article: Millions in the US could face massive consequences unless McCarthy can navigate out of a debt trap he set for Biden with category: Others
# Inserted article: White homeowner accused of shooting a Black teen who rang his doorbell turns himself in to face criminal charges with category: Others
# Inserted article: Newly released video shows scene of Jeremy Renner's snowplow accident with category: Others
# Inserted article: Jake Gyllenhaal and Jamie Lee Curtis spent the Covid-19 lockdown together with category: Others
# Inserted article: Toddler crawls through White House fence, prompts Secret Service response with category: Others
# Inserted article: Jamie Foxx remains hospitalized nearly a week after 'medical complication' with category: Others
# Inserted article: A 13-year-old dies after participating in a Benadryl TikTok 'challenge' with category: Others
# Inserted article: See pizza delivery guy take out suspect fleeing police with category: Others
# Inserted article: Netflix is winding down its DVD business after 25 years with category: Others
# Inserted article: FTC chair Lina Khan warns AI could 'turbocharge' fraud and scams with category: Others
# Inserted article: Eating too much of these foods is driving the rise in type 2 diabetes, study says with category: Others
# Inserted article: ADHD medication abuse in schools is a 'wake-up call' with category: Others
# Inserted article: Apple CEO was presented with an original Macintosh. See his reaction with category: Others
# Inserted article: Democrats bash Justice Clarence Thomas but their plan to investigate ethics allegations is unclear with category: Others
# Inserted article: Russia is 'going backwards' in equipment and deploying post WWII-era tanks, according to Western officials with category: Others
# Inserted article: Two Russians claiming to be former Wagner commanders admit killing children and civilians in Ukraine with category: Others
# Inserted article: 'My stomach is hurting from laughing': Hear panelist's reaction to DeSantis' threat to Disney with category: Others
# Inserted article: GOP prepared to block vote to replace Feinstein on Senate Judiciary with category: Positive/Uplifting
# Inserted article: Oklahoma governor calls on officials to resign over recording of racist and threatening remarks with category: Others
# Inserted article: McCarthy slams Biden in handling of US debt with category: Others
# Inserted article: US warns Russia not to touch American nuclear technology at Ukrainian nuclear plant with category: Others
# Inserted article: Repeated gunshots fired on live TV as ex-lawmaker shot by assassins with category: Others
# Inserted article: FDA clears the way for additional bivalent boosters for certain vulnerable individuals with category: Others
# Inserted article: Maine authorities detained a person of interest after 4 people were found dead in a home and 3 others shot while driving with category: Others
# Inserted article: Southwest says flights resumed after delays caused by 'tech issues' with category: Others
# Inserted article: Damar Hamlin cleared to resume football activities after January cardiac arrest with category: Others
# Inserted article: Pilot makes history after landing on top of a 56-story hotel with category: Others
# Inserted article: Top US Navy admiral defends non-binary sailor amid some Republican criticism with category: Others
# Inserted article: Fulton County DA says fake Trump electors are incriminating one another and wants lawyer disqualified with category: Others
# Inserted article: High speed trains are racing across the world. But not in America with category: Others
# Inserted article: Podcast: One country musician is calling for other artists to oppose assault rifles with category: Others
# Inserted article: Here's what you need to know if you haven't filed your return yet — and even if you have with category: Others
# Inserted article: Undocumented immigrants are paying their taxes today, too with category: Others
# Inserted article: Opinion: Why millionaires like us want to pay more in taxes with category: Positive/Uplifting
# Inserted article: 'World's longest' purpose-built cycling tunnel opens in Norway with category: Others
# Inserted article: Artist rejects photo prize after AI-generated image wins award with category: Others
# Inserted article: These ships disappeared in Lake Superior a century ago. Watch as they're found again with category: Others
# Inserted article: Erotic images of seniors show sex and intimacy in new light with category: Others
# Inserted article: China's economy is off to a solid start, rising 4.5% in Q1 2023 with category: Others
# Inserted article: Even when wives make as much as husbands, they still do more at home with category: Others
# Inserted article: McDonald's is upgrading its burgers with category: Others
# Inserted article: Google-parent stock drops on fears it could lose search market share to AI-powered rivals with category: Others
# Inserted article: Bidets save you money and reduce waste — we tested the best options out there with category: Others
# Inserted article: 50+ products to make your life easier and our planet cleaner with category: Others
# Inserted article: Mother's Day is around the corner. Here are 50+ thoughtful gifts she'll love with category: Others
# Inserted article: A head-to-toe guide of how men should dress this spring, and where they should shop with category: Others
# Inserted article: 42 of the most useful travel products you can buy on Amazon with category: Others
# Inserted article: The 7 best high-yield savings accounts of April 2023 with category: Others
# Inserted article: Taxes are due tomorrow. Here's how to file for an extension with category: Others
# Inserted article: Composting is an easy way to reduce food waste. Here's how to do it with category: Others
# Inserted article: We stopped using aluminum foil for cooking and you should too. Here's what to use instead with category: Others
# Inserted article: The beloved Dyson Supersonic hair dryer is at its lowest price ever with category: Others
# Inserted article: Everything you need to know about Way Day 2023, Wayfair's biggest sale of the year with category: Others
# Inserted article: The 10 best Amazon deals to shop this week with category: Others
# Inserted article: Mifepristone saved my life with category: Terrorism / protest / political unrest / riot
# Inserted article: The 2024 presidential alternative many voters will want with category: Others
# Inserted article: Why isn't the House Judiciary Committee looking into Thomas? with category: Others
# Inserted article: Top secrets come spilling out with category: Others
# Inserted article: How did Sudan go from casting off despotic rule to this? with category: Others
# Inserted article: Michelle Yeoh set to return in new 'Star Trek' movie with category: Others
# Inserted article: Recap: 'Succession' finds dark humor in the aftershocks with category: Positive/Uplifting
# Inserted article: 'Yellowjackets' leans hard into '90s music nostalgia, and we're here for it with category: Others
# Inserted article: Jeremy Renner revisits 'the amazing group of people' who helped him recover from his accident with category: Others
# Inserted article: Review: 'Barry' takes a whack at its farewell season with category: Others
# Parsing feed: http://qz.com/feed
# Inserted article: The 10 most valuable private companies in the world with category: Others
# Inserted article: 15 cities with the most expensive fast food in America with category: Positive/Uplifting
# Inserted article: Ozempic and prescription weight loss drugs: How they work, what they cost, side effects, and everything to know with category: Others
# Inserted article: Domino's brings back 'emergency pizza' promotion that drove sales with category: Others
# Inserted article: Can Costco compete online without killing the 'treasure hunt'? with category: Others
# Inserted article: Americans are slowing down on their credit card spending — here’s why with category: Others
# Inserted article: Lyft rolls out new payment measures to gain more drivers with category: Others
# Inserted article: FAANG and data center stocks are a buy to cash in on AI's next phase, strategist says with category: Others
# Inserted article: Luxury car sales are tanking as drivers look for cheaper options with category: Others
# Inserted article: All the airports closing for Hurricane Milton with category: Natural Disasters
# Inserted article: The next Nvidia? Data center stocks could be a goldmine, strategist says with category: Others
# Inserted article: Home Depot says corporate employees have to try working in actual stores with category: Others
# Inserted article: Look inside Clint Eastwood’s California home that just sold for more than $18 million with category: Others
# Inserted article: WeightWatchers is getting in on the off-brand weight loss drug game — and selling them cheap with category: Others
# Inserted article: A self-driving truck startup wants Waymo, Cruise, and others to follow its lead on safety with category: Others
# Inserted article: Kamala Harris wants Medicare to help cover in-home eldercare. Here's how she plans to pay for it with category: Others
# Inserted article: Two AI pioneers won the Nobel Prize for their work in machine learning with category: Others
# Inserted article: Toyota is delaying plans to make electric cars in America with category: Others
# Inserted article: Bitcoin creator Satoshi Nakamoto unmasked: Will HBO reveal who really made the cryptocurrency? with category: Others
# Inserted article: Even a grocery store is offering free streaming perks now with category: Others
# Inserted article: 10 cities where low mortgage rates have homeowners locked in 'golden handcuffs' with category: Others
# Inserted article: Tesla's big robotaxi event might not even have real cars with category: Others
# Inserted article: SpaceX says it could launch Starship soon if the FAA lets it with category: Others
# Inserted article: Uber will use ChatGPT to get more people to use EVs with category: Others
# Inserted article: Everything to know about Nvidia, from the stock to its AI chips with category: Others
# Inserted article: Why are the world's wealthiest families flocking to family offices? with category: Others
# Inserted article: The top 10 mental health apps to try on World Mental Health Day with category: Others
# Inserted article: Costco's gold bars are selling out fast with category: Others
# Inserted article: FTX shareholders could get $1 billion after crypto firm is cleared to fully repay customers with category: Others
# Inserted article: Christine McVie’s Fleetwood Mac scrapbook, Dianne Feinstein’s books, and an iconic Marilyn Monroe portrait: this week’s auction block roundup with category: Others
# Inserted article: McDonald's is suing Tyson Foods for allegedly choking the beef supply chain to raise prices with category: Others
# Inserted article: Donald Trump's plans would cut taxes on the richest 5% of America — and raise them for everyone else with category: Others
# Inserted article: Super Micro Computer stock surges 15% on big AI demand with category: Others
# Inserted article: A hot meal on a transatlantic JetBlue flight will now cost extra with category: Others
# Inserted article: EV chargers that feel more like a gas station are coming with category: Others
# Inserted article: Bankrupt EV startup Fisker left its abandoned headquarters in 'complete disarray' with category: Others
# Inserted article: A Frontier Airlines flight trailed flames as it landed with category: Others
# Inserted article: A classic Hamptons home, cliffside Beverly Hills bungalow and mansion-sized Manhattan townhouse: This week’s real estate roundup with category: Others
# Inserted article: Trump Media stock spikes 15% after Elon Musk came to a campaign rally with category: Others
# Inserted article: Panera Bread settled a Charged Lemonade lawsuit after a student's death with category: Others
# Inserted article: Tesla Cybertrucks are still being insured by Geico — despite claims otherwise with category: Terrorism / protest / political unrest / riot
# Inserted article: Boeing is restarting talks to end a strike some compare to an economic Hurricane Helene with category: Natural Disasters
# Inserted article: Who really created Bitcoin? A new HBO documentary claims it has the answer with category: Others
# Inserted article: Martin Shkreli can't escape his $64 million fine with category: Others
# Inserted article: Red Lobster's new CEO admits it: 'Endless Shrimp' was a disaster with category: Others
# Inserted article: Fisker is dead. But its legal problems are very much alive with category: Others
# Inserted article: Donald Trump would balloon the federal debt by twice as much as Kamala Harris, report says with category: Others
# Inserted article: FTX token, Sui, Aptos, Popcat, and more: Cryptocurrencies to watch this week with category: Others
# Parsing feed: http://feeds.foxnews.com/foxnews/politics
# Inserted article: Arizona begins in-person and absentee voting, here's what you need to know with category: Terrorism / protest / political unrest / riot
# Inserted article: Biden-Harris admin ‘taking advice from foreign governments’ on policing speech, lawmaker charges with category: Others
# Inserted article: Georgia Dems chair reveals message to undecided GOP voters as Harris works to build broad base with category: Others
# Inserted article: Trump-backed House candidate rips Biden's 'joke' border policy for inviting gang violence to swing state with category: Others
# Inserted article: From kissy-face sitdown on ‘The View’ to a tougher grilling on ‘60 Minutes,’ Kamala Harris is making news with category: Positive/Uplifting
# Inserted article: Tim Walz calls for elimination of Electoral College at California fundraiser, says 'it needs to go' with category: Others
# Inserted article: Israel’s Minister of Defense cancels visit to Pentagon amid Middle East conflict escalation with category: Others
# Inserted article: 'Abandon Harris' group endorses Jill Stein over 'pro-genocide candidate' Kamala Harris with category: Terrorism / protest / political unrest / riot
# Inserted article: US officials reveal fate of nabbed Tajikistan illegal immigrants with alleged ISIS ties with category: Others
# Inserted article: Fox News Politics: Harris on '60 minutes': Joe 2.0? with category: Others
# Inserted article: Biden undermines Harris claim that Ron DeSantis is politicizing hurricane response: 'Doing a great job' with category: Natural Disasters
# Inserted article: Supreme Court signals support for Biden administration regulation of 'ghost gun' kits with category: Terrorism / protest / political unrest / riot
# Inserted article: Reporter's Notebook: With no government shutdown, it feels like Christmas in September with category: Others
# Inserted article: Prospects of a deal with Israel fade away as Saudis invite Iranian foreign minister to visit with category: Others
# Inserted article: Early voting means 'election season' has already begun with category: Terrorism / protest / political unrest / riot
# Inserted article: Overseas meth sent to US election building shuts down office for hours with category: Terrorism / protest / political unrest / riot
# Inserted article: Kamala Harris' tough words on Iran confounds critics with category: Others
# Inserted article: New poll shows Harris taking a slim lead over Trump thanks to support from a surprising group with category: Terrorism / protest / political unrest / riot
# Inserted article: North Carolina residents will see changes to early voting after Hurricane Helene with category: Terrorism / protest / political unrest / riot
# Inserted article: New poll reveals which voter group are fueling Trump to a narrow edge over Harris in battleground with category: Others
# Inserted article: Texas AG demands Biden-Harris admin help verify citizenship of nearly 500K registered voters with category: Others
# Inserted article: SEE IT: Wisconsin dairy farmer says 'no question' Trump admin was 'much better' than Biden-Harris with category: Others
# Inserted article: Biden cancels overseas trip as Milton bears down on Florida; DeSantis tells VP 'it's not about you Kamala' with category: Natural Disasters
# Inserted article: Mayorkas rips 'politicized' atmosphere over FEMA disaster response amid GOP criticism: 'It sows distrust' with category: Natural Disasters
# Inserted article: Hispanic voters rail against 'dishonest' Biden-Harris border record as poll shows Trump gaining in key states with category: Others
# Parsing feed: http://feeds.reuters.com/reuters/businessNews
# Parsing feed: http://feeds.feedburner.com/NewshourWorld
# Inserted article: Xi Jinping celebrates China’s rising power — and his own with category: Positive/Uplifting
# Inserted article: The battle for Mosul is over, but this hidden ISIS danger could lurk for years with category: Others
# Inserted article: As Rohingya refugees continue to flee from persecution, here’s how you can help with category: Others
# Inserted article: Tillerson: ‘Heartbreaking’ reports of suffering in Myanmar with category: Others
# Inserted article: Far-right groups gain ground in Sweden and Germany amid migrant influx with category: Terrorism / protest / political unrest / riot
# Inserted article: U.S.-backed Syrian forces recapture Raqqa from Islamic State group with category: Others
# Inserted article: WATCH: Trump and Greek prime minister hold joint news conference with category: Others
# Inserted article: U.S., Japan agree to maximize diplomatic pressure on North Korea with category: Others
# Inserted article: News Wrap: Dozens missing after deadly Mogadishu truck bombing with category: Others
# Inserted article: Why a power struggle has broken out over Kirkuk with category: Others
# Inserted article: Rex Tillerson says continue diplomacy with North Korea ‘until first bomb drops’ with category: Others
# Inserted article: Iraqi, Kurdish forces in standoff, weeks after Kurdish vote for independence with category: Others
# Inserted article: South Sudan civil war causes Africa’s worst refugee crisis with category: Others
# Inserted article: Hundreds dead after massive truck bomb strikes Mogadishu with category: Others
# Inserted article: Column: Why reporting from South Sudan is so difficult — and critically needed with category: Others
# Parsing feed: https://feeds.bbci.co.uk/news/world/asia/india/rss.xml
# Inserted article: Kashmir and Haryana prove India exit polls wrong with category: Terrorism / protest / political unrest / riot
# Inserted article: 'Our son died. Now we can use his sperm to have a grandchild' with category: Others
# Inserted article: Indian financial aid opens 'new chapter' with Maldives with category: Others
# Inserted article: Why are there so many dropped catches at T20 World Cup? with category: Others
# Inserted article: Climbers rescued after three days in the Himalayas with category: Others
# Inserted article: India government says criminalising marital rape 'excessively harsh' with category: Others
# Inserted article: Maldives president visits India amid trouble in tourist paradise with category: Others
# Inserted article: The Polish artist who painted Hindu gods in Indian palaces with category: Others
# Inserted article: How India became a Test cricket powerhouse with category: Others
# Inserted article: India's iconic tramcars set to ride into Kolkata sunset with category: Others
# Inserted article: My mission is to take Tamil music global, says Sid Sriram with category: Others
# Inserted article: India's top court saves a poor student's college dream with category: Others
# Inserted article: The 'mastermind' behind India's biggest jailbreak with category: Others
# Inserted article: The world’s diamond polishing capital feels Ukraine war impact with category: Others
# Inserted article: Sold out in minutes, resold for millions: Coldplay tickets spark outrage in India with category: Others
# Inserted article: A famed holy sweet in an unsavoury row in India with category: Others
# Inserted article: Your essential guide to the ICC Women's T20 World Cup with category: Others
# Inserted article: The Kashmiri politician whose return from jail ruffled feathers with category: Others
# Inserted article: Death of Indian employee sparks debate on 'toxic work culture' with category: Others
# Inserted article: Tigers and crocs make mangrove preservation tough work with category: Others
# Inserted article: How Punjabi megastar Diljit Dosanjh is inspiring the next gen with category: Others
# Inserted article: Hema committee report: Why are India's biggest film stars silent? with category: Others
# Inserted article: Volunteers dying as Russia’s war dead tops 70,000 with category: Others
# Inserted article: Why hundreds of Samsung workers are protesting in India with category: Terrorism / protest / political unrest / riot
# Inserted article: 'Please save me': The Indians duped into fighting for Russia with category: Others
# Inserted article: After a decade, Kashmir votes in historic elections with category: Terrorism / protest / political unrest / riot
# Inserted article: The German woman who helped build an Indian university with category: Others
# Inserted article: India's oldest trams may soon be brought to a halt with category: Others
# Inserted article: Kolkata night protest: 'Today I witnessed history' with category: Terrorism / protest / political unrest / riot
# Inserted article: Watch: Thousands of women protest about rape and murder of doctor in India with category: Terrorism / protest / political unrest / riot
# Inserted article: Watch: Building collapses into river in Himachal Pradesh with category: Others
# Inserted article: Watch: Blue screens, queues and airport delays worldwide with category: Others
# Inserted article: Lavish Ambani wedding divides opinions in India with category: Others
# Inserted article: Former PMs, film and sports stars join Ambani wedding with category: Others
# Inserted article: WATCH: Families mourn victims of deadly India crush with category: Others
# Inserted article: Watch: Delhi airport roof collapses due to heavy rain with category: Others
# Inserted article: What worked for India's Modi - and what didn’t? with category: Terrorism / protest / political unrest / riot
# Inserted article: Arrests, accusations and AI: India’s election unpacked with category: Terrorism / protest / political unrest / riot

# %% [markdown]
# ### Getting Started
#
# First things first, the script kicks off by importing a couple of key libraries: `feedparser` and `psycopg2`. The `feedparser` library is used to pull in and parse those RSS feeds, which makes retrieving articles a breeze. On the other hand, `psycopg2` is our go-to for connecting to a PostgreSQL database, letting us easily save our articles.
#
# ### Setting Up Categories
#
# Next, we define a dictionary called `categories` that groups different news types into categories based on some relevant keywords. We’ve got categories like "Terrorism / protest / political unrest / riot," "Positive/Uplifting," and "Natural Disasters." Each category has a list of keywords that help us figure out where each article fits.
#
# ### Classifying Articles
#
# Now, here’s where the magic happens. We’ve got a function called `classify_article` that takes a piece of text (like an article title) and checks it against our keyword lists. It’s pretty straightforward: if it finds any of the keywords in the text, it returns the associated category. If nothing matches, it just goes with "Others."
#
# ### Connecting to the Database
#
# Once we’re set up with our categories, the script connects to the PostgreSQL database using the provided credentials (like username, password, and so on). This connection is crucial because we’ll be storing our articles there.
#
# ### Parsing RSS Feeds
#
# The script also has a list of RSS feed URLs from which it pulls articles. It goes through each URL, parsing the feeds with `feedparser`. For every feed, it digs into the entries (or articles) and extracts important details like the title, link, and published date. If any of these are missing, it fills in with a default value like "No title."
#
# ### Getting Unique IDs and Classifying
#
# To make each article unique, the script generates an ID by combining the feed index and the entry index. Then it classifies the article using the earlier defined function. This step helps us categorize the articles based on their content.
#
# ### Storing in the Database
#
# Next up is the part where the script tries to insert the article data into the database. It does this using an SQL `INSERT` statement that includes the article's ID, title, link, published date, and the category we just assigned. If there’s a conflict—like if the same link is already in the database—it updates the existing record instead of creating a duplicate.
#
# ### Committing Changes and Handling Errors
#
# After each successful insertion or update, the script commits those changes to the database, making sure everything is saved. And, of course, it has error handling in place. If something goes wrong during the insertion, it prints an error message to help troubleshoot.
#
# ### Wrapping Up
#
# Finally, when everything is done, the script closes the database connection and cleans up.
